# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import json

# %%
IMG_SIZE = (224, 224)
BATCH_SIZE = 32

TRAIN_DIR = r"C:\Users\KristianHaltenJensen\Noroff\Bachelor\LWDCD\dataset_split\train"
VAL_DIR = r"C:\Users\KristianHaltenJensen\Noroff\Bachelor\LWDCD\dataset_split\val"
TEST_DIR = r"C:\Users\KristianHaltenJensen\Noroff\Bachelor\LWDCD\dataset_split\test"

train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.15,
    height_shift_range=0.15,
    zoom_range=0.15,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest"
)

val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=True
)

val_generator = val_datagen.flow_from_directory(
    VAL_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

num_classes = train_generator.num_classes
# Out:
# Found 2351 images belonging to 3 classes.
# Found 506 images belonging to 3 classes.
# Found 505 images belonging to 3 classes.

# %%
base_model = ResNet50(
    weights="imagenet",
    include_top=False,
    input_shape=(224, 224, 3)
)

base_model.trainable = False

# %%
inputs = layers.Input(shape=(224, 224, 3))
x = base_model(inputs, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.BatchNormalization()(x)
x = layers.Dense(256, activation="relu")(x)
x = layers.Dropout(0.4)(x)
outputs = layers.Dense(num_classes, activation="softmax")(x)

model = models.Model(inputs, outputs)
model.summary()

model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ resnet50 (Functional)                │ (None, 7, 7, 2048)          │      23,587,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 2048)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 2048)                │           8,192 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         524,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │             771 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 24,121,219 (92.02 MB)
#  Trainable params: 529,411 (2.02 MB)
#  Non-trainable params: 23,591,808 (90.00 MB)

# %%
callbacks = [
    EarlyStopping(
        monitor="val_loss",
        patience=5,
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.2,
        patience=2,
        min_lr=1e-7,
        verbose=1
    ),
    ModelCheckpoint(
        "ResNet50_transfer_best.keras",
        monitor="val_accuracy",
        save_best_only=True,
        verbose=1
    )
]

# %%
history_head = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=50,
    callbacks=callbacks
)
# Out:
# C:\Users\KristianHaltenJensen\anaconda4\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5508 - loss: 1.1806
# Epoch 1: val_accuracy improved from -inf to 0.82806, saving model to ResNet50_transfer_best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 184s 2s/step - accuracy: 0.5524 - loss: 1.1768 - val_accuracy: 0.8281 - val_loss: 0.5270 - learning_rate: 1.0000e-04
# Epoch 2/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8043 - loss: 0.5448
# Epoch 2: val_accuracy improved from 0.82806 to 0.85771, saving model to ResNet50_transfer_best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 158s 2s/step - accuracy: 0.8043 - loss: 0.5450 - val_accuracy: 0.8577 - val_loss: 0.3861 - learning_rate: 1.0000e-04
# Epoch 3/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8224 - loss: 0.4815
# Epoch 3: val_accuracy improved from 0.85771 to 0.87352, saving model to ResNet50_transfer_best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 161s 2s/step - accuracy: 0.8224 - loss: 0.4813 - val_accuracy: 0.8735 - val_loss: 0.3313 - learning_rate: 1.0000e-04
# Epoch 4/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8415 - loss: 0.4062
# Epoch 4: val_accuracy improved from 0.87352 to 0.89921, saving model to ResNet50_transfer_best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - accuracy: 0.8415 - loss: 0.4061 - val_accuracy: 0.8992 - val_loss: 0.2789 - learning_rate: 1.0000e-04
# Epoch 5/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8720 - loss: 0.3512
# Epoch 5: val_accuracy improved from 0.89921 to 0.91304, saving model to ResNet50_transfer_best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.8719 - loss: 0.3514 - val_accuracy: 0.9130 - val_loss: 0.2481 - learning_rate: 1.0000e-04
# Epoch 6/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8781 - loss: 0.3215
# Epoch 6: val_accuracy improved from 0.91304 to 0.92292, saving model to ResNet50_transfer_best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 157s 2s/step - accuracy: 0.8782 - loss: 0.3215 - val_accuracy: 0.9229 - val_loss: 0.2300 - learning_rate: 1.0000e-04
# Epoch 7/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8870 - loss: 0.2952
# Epoch 7: val_accuracy did not improve from 0.92292
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 153s 2s/step - accuracy: 0.8870 - loss: 0.2953 - val_accuracy: 0.9229 - val_loss: 0.2179 - learning_rate: 1.0000e-04
# Epoch 8/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9026 - loss: 0.2602
# Epoch 8: val_accuracy improved from 0.92292 to 0.92885, saving model to ResNet50_transfer_best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 176s 2s/step - accuracy: 0.9026 - loss: 0.2605 - val_accuracy: 0.9289 - val_loss: 0.1977 - learning_rate: 1.0000e-04
# Epoch 9/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9034 - loss: 0.2542
# Epoch 9: val_accuracy did not improve from 0.92885
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 189s 3s/step - accuracy: 0.9034 - loss: 0.2541 - val_accuracy: 0.9229 - val_loss: 0.1981 - learning_rate: 1.0000e-04
# Epoch 10/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9087 - loss: 0.2431
# Epoch 10: val_accuracy did not improve from 0.92885
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 159s 2s/step - accuracy: 0.9087 - loss: 0.2431 - val_accuracy: 0.9249 - val_loss: 0.1871 - learning_rate: 1.0000e-04
# Epoch 11/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9252 - loss: 0.1983
# Epoch 11: val_accuracy improved from 0.92885 to 0.93281, saving model to ResNet50_transfer_best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9252 - loss: 0.1983 - val_accuracy: 0.9328 - val_loss: 0.1836 - learning_rate: 1.0000e-04
# Epoch 12/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9214 - loss: 0.2017
# Epoch 12: val_accuracy improved from 0.93281 to 0.94269, saving model to ResNet50_transfer_best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - accuracy: 0.9214 - loss: 0.2017 - val_accuracy: 0.9427 - val_loss: 0.1652 - learning_rate: 1.0000e-04
# Epoch 13/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9165 - loss: 0.2036
# Epoch 13: val_accuracy did not improve from 0.94269
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 172s 2s/step - accuracy: 0.9165 - loss: 0.2036 - val_accuracy: 0.9387 - val_loss: 0.1635 - learning_rate: 1.0000e-04
# Epoch 14/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9308 - loss: 0.1878
# Epoch 14: val_accuracy did not improve from 0.94269
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.9308 - loss: 0.1878 - val_accuracy: 0.9387 - val_loss: 0.1659 - learning_rate: 1.0000e-04
# Epoch 15/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9361 - loss: 0.1823
# Epoch 15: val_accuracy did not improve from 0.94269
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 155s 2s/step - accuracy: 0.9360 - loss: 0.1824 - val_accuracy: 0.9427 - val_loss: 0.1553 - learning_rate: 1.0000e-04
# Epoch 16/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9307 - loss: 0.1810
# Epoch 16: val_accuracy did not improve from 0.94269
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 166s 2s/step - accuracy: 0.9307 - loss: 0.1809 - val_accuracy: 0.9387 - val_loss: 0.1496 - learning_rate: 1.0000e-04
# Epoch 17/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9415 - loss: 0.1566
# Epoch 17: val_accuracy did not improve from 0.94269
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 193s 3s/step - accuracy: 0.9415 - loss: 0.1566 - val_accuracy: 0.9407 - val_loss: 0.1416 - learning_rate: 1.0000e-04
# Epoch 18/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9504 - loss: 0.1626
# Epoch 18: val_accuracy improved from 0.94269 to 0.94862, saving model to ResNet50_transfer_best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 145s 2s/step - accuracy: 0.9504 - loss: 0.1626 - val_accuracy: 0.9486 - val_loss: 0.1357 - learning_rate: 1.0000e-04
# Epoch 19/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9522 - loss: 0.1500
# Epoch 19: val_accuracy did not improve from 0.94862
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 131s 2s/step - accuracy: 0.9521 - loss: 0.1500 - val_accuracy: 0.9407 - val_loss: 0.1483 - learning_rate: 1.0000e-04
# Epoch 20/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9553 - loss: 0.1377
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
#
# Epoch 20: val_accuracy did not improve from 0.94862
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.9552 - loss: 0.1379 - val_accuracy: 0.9447 - val_loss: 0.1376 - learning_rate: 1.0000e-04
# Epoch 21/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9391 - loss: 0.1474
# Epoch 21: val_accuracy did not improve from 0.94862
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.9391 - loss: 0.1472 - val_accuracy: 0.9447 - val_loss: 0.1350 - learning_rate: 2.0000e-05
# Epoch 22/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9470 - loss: 0.1382
# Epoch 22: val_accuracy did not improve from 0.94862
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 172s 2s/step - accuracy: 0.9469 - loss: 0.1384 - val_accuracy: 0.9427 - val_loss: 0.1370 - learning_rate: 2.0000e-05
# Epoch 23/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9387 - loss: 0.1511
# Epoch 23: val_accuracy did not improve from 0.94862
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 145s 2s/step - accuracy: 0.9388 - loss: 0.1511 - val_accuracy: 0.9407 - val_loss: 0.1343 - learning_rate: 2.0000e-05
# Epoch 24/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9517 - loss: 0.1426
# Epoch 24: val_accuracy did not improve from 0.94862
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - accuracy: 0.9516 - loss: 0.1426 - val_accuracy: 0.9486 - val_loss: 0.1340 - learning_rate: 2.0000e-05
# Epoch 25/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9582 - loss: 0.1175
# Epoch 25: val_accuracy did not improve from 0.94862
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 144s 2s/step - accuracy: 0.9582 - loss: 0.1176 - val_accuracy: 0.9486 - val_loss: 0.1339 - learning_rate: 2.0000e-05
# Epoch 26/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9568 - loss: 0.1327
# Epoch 26: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
#
# Epoch 26: val_accuracy did not improve from 0.94862
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 134s 2s/step - accuracy: 0.9567 - loss: 0.1328 - val_accuracy: 0.9447 - val_loss: 0.1347 - learning_rate: 2.0000e-05
# Epoch 27/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9537 - loss: 0.1262
# Epoch 27: val_accuracy did not improve from 0.94862
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 146s 2s/step - accuracy: 0.9537 - loss: 0.1263 - val_accuracy: 0.9447 - val_loss: 0.1359 - learning_rate: 4.0000e-06
# Epoch 28/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9517 - loss: 0.1293
# Epoch 28: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
#
# Epoch 28: val_accuracy did not improve from 0.94862
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 132s 2s/step - accuracy: 0.9517 - loss: 0.1294 - val_accuracy: 0.9447 - val_loss: 0.1357 - learning_rate: 4.0000e-06
# Epoch 29/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9555 - loss: 0.1404
# Epoch 29: val_accuracy did not improve from 0.94862
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 166s 2s/step - accuracy: 0.9554 - loss: 0.1404 - val_accuracy: 0.9427 - val_loss: 0.1352 - learning_rate: 8.0000e-07
# Epoch 30/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9492 - loss: 0.1384
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
#
# Epoch 30: val_accuracy did not improve from 0.94862
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 170s 2s/step - accuracy: 0.9492 - loss: 0.1382 - val_accuracy: 0.9427 - val_loss: 0.1359 - learning_rate: 8.0000e-07
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 25.

# %%
with open("resnet50_head_history_LWDCD.json", "w") as f:
    json.dump(history_head.history, f)

# %%
base_model.trainable = True

for layer in base_model.layers[:120]:
    layer.trainable = False

model.compile(
    optimizer=Adam(learning_rate=1e-5),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

history_fine = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=50,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9152 - loss: 0.2103
# Epoch 1: val_accuracy did not improve from 0.94862
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 199s 2s/step - accuracy: 0.9152 - loss: 0.2103 - val_accuracy: 0.9466 - val_loss: 0.1298 - learning_rate: 1.0000e-05
# Epoch 2/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9398 - loss: 0.1654
# Epoch 2: val_accuracy improved from 0.94862 to 0.96245, saving model to ResNet50_transfer_best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - accuracy: 0.9398 - loss: 0.1654 - val_accuracy: 0.9625 - val_loss: 0.1117 - learning_rate: 1.0000e-05
# Epoch 3/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9486 - loss: 0.1452
# Epoch 3: val_accuracy improved from 0.96245 to 0.96443, saving model to ResNet50_transfer_best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9485 - loss: 0.1453 - val_accuracy: 0.9644 - val_loss: 0.1048 - learning_rate: 1.0000e-05
# Epoch 4/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9405 - loss: 0.1504
# Epoch 4: val_accuracy did not improve from 0.96443
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 169s 2s/step - accuracy: 0.9406 - loss: 0.1503 - val_accuracy: 0.9625 - val_loss: 0.0982 - learning_rate: 1.0000e-05
# Epoch 5/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9585 - loss: 0.1266
# Epoch 5: val_accuracy improved from 0.96443 to 0.96838, saving model to ResNet50_transfer_best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 190s 3s/step - accuracy: 0.9586 - loss: 0.1264 - val_accuracy: 0.9684 - val_loss: 0.0902 - learning_rate: 1.0000e-05
# Epoch 6/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9599 - loss: 0.1092
# Epoch 6: val_accuracy improved from 0.96838 to 0.97628, saving model to ResNet50_transfer_best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 201s 3s/step - accuracy: 0.9598 - loss: 0.1093 - val_accuracy: 0.9763 - val_loss: 0.0817 - learning_rate: 1.0000e-05
# Epoch 7/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9630 - loss: 0.0989
# Epoch 7: val_accuracy did not improve from 0.97628
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 184s 2s/step - accuracy: 0.9629 - loss: 0.0990 - val_accuracy: 0.9723 - val_loss: 0.0835 - learning_rate: 1.0000e-05
# Epoch 8/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9627 - loss: 0.1002
# Epoch 8: val_accuracy did not improve from 0.97628
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.9628 - loss: 0.1001 - val_accuracy: 0.9743 - val_loss: 0.0801 - learning_rate: 1.0000e-05
# Epoch 9/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9683 - loss: 0.0908
# Epoch 9: val_accuracy did not improve from 0.97628
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 159s 2s/step - accuracy: 0.9683 - loss: 0.0908 - val_accuracy: 0.9644 - val_loss: 0.0829 - learning_rate: 1.0000e-05
# Epoch 10/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9729 - loss: 0.0803
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
#
# Epoch 10: val_accuracy did not improve from 0.97628
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 197s 3s/step - accuracy: 0.9728 - loss: 0.0802 - val_accuracy: 0.9644 - val_loss: 0.0836 - learning_rate: 1.0000e-05
# Epoch 11/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9778 - loss: 0.0734
# Epoch 11: val_accuracy did not improve from 0.97628
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 192s 3s/step - accuracy: 0.9777 - loss: 0.0735 - val_accuracy: 0.9704 - val_loss: 0.0813 - learning_rate: 2.0000e-06
# Epoch 12/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9774 - loss: 0.0572
# Epoch 12: ReduceLROnPlateau reducing learning rate to 3.999999989900971e-07.
#
# Epoch 12: val_accuracy did not improve from 0.97628
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 189s 3s/step - accuracy: 0.9774 - loss: 0.0572 - val_accuracy: 0.9664 - val_loss: 0.0801 - learning_rate: 2.0000e-06
# Epoch 13/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9773 - loss: 0.0699
# Epoch 13: val_accuracy did not improve from 0.97628
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 172s 2s/step - accuracy: 0.9773 - loss: 0.0700 - val_accuracy: 0.9684 - val_loss: 0.0802 - learning_rate: 4.0000e-07
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 8.

# %%
with open("resnet50_finetune_history_LWDCD.json", "w") as f:
    json.dump(history_fine.history, f)

# %%
test_loss, test_acc = model.evaluate(test_generator)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - accuracy: 0.9673 - loss: 0.1550
# Test accuracy: 0.9663

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

pred_probs = model.predict(test_generator)
y_pred = np.argmax(pred_probs, axis=1)
y_true = test_generator.classes
class_names = list(test_generator.class_indices.keys())

print(classification_report(y_true, y_pred, target_names=class_names))
print(confusion_matrix(y_true, y_pred))
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step
#                   precision    recall  f1-score   support
#
#    Healthy Wheat       0.97      0.97      0.97       175
#        Leaf Rust       0.98      0.96      0.97       190
# Wheat Loose Smut       0.94      0.98      0.96       140
#
#         accuracy                           0.97       505
#        macro avg       0.96      0.97      0.97       505
#     weighted avg       0.97      0.97      0.97       505
#
# [[169   1   5]
#  [  4 182   4]
#  [  1   2 137]]

# %%
model.save("ResNet50_finetuned_LWDCD.keras")

# %%
model.save("ResNet50_head_LWDCD.keras")

# %%
import os
import json
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2

from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image

# =========================
# PATHS
# =========================
MODEL_PATH = "WheatDiseaseDetection_ResNet50.keras"
CLASS_JSON = "class_names.json"



IMAGE_PATHS = [
    r"C:\Users\KristianHaltenJensen\Noroff\Bachelor\Images\leaf rust.jpg",
    r"C:\Users\KristianHaltenJensen\Noroff\Bachelor\Images\Healthy leaf.jpg",
    r"C:\Users\KristianHaltenJensen\Noroff\Bachelor\Images\wheat loose smut.jpg",
]

IMG_SIZE = (224, 224)

# =========================
# LOAD MODEL
# =========================
model = tf.keras.models.load_model(MODEL_PATH, compile=False)

with open(CLASS_JSON, "r", encoding="utf-8") as f:
    class_names = json.load(f)

print("Loaded model.")
print("Top-level layers:")
for i, layer in enumerate(model.layers):
    print(i, layer.name, layer.__class__.__name__)

# Get the nested ResNet50 backbone
base_model = model.get_layer("resnet50")
last_conv_layer_name = "conv5_block3_out"   # best choice for ResNet50

print("Backbone:", base_model.name)
print("Using last conv layer:", last_conv_layer_name)

# =========================
# PREPROCESS
# =========================
def load_and_preprocess_image(img_path, target_size=IMG_SIZE):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)
    return img_array

# =========================
# GRAD-CAM FOR NESTED RESNET50
# =========================
def make_gradcam_heatmap(img_array, model, base_model, pred_index=None):
    # Get the classifier head layers from the full model
    gap_layer = model.get_layer("global_average_pooling2d_2")
    dropout_layer = model.get_layer("dropout_2")
    classifier_layer = model.get_layer("dense")

    img_tensor = tf.convert_to_tensor(img_array, dtype=tf.float32)

    with tf.GradientTape() as tape:
        # Forward pass through ResNet50 backbone only
        conv_outputs = base_model(img_tensor, training=False)   # shape: (1, 7, 7, 2048)
        tape.watch(conv_outputs)

        # Forward pass through your classifier head manually
        x = gap_layer(conv_outputs)
        x = dropout_layer(x, training=False)
        preds = classifier_layer(x)

        if pred_index is None:
            pred_index = tf.argmax(preds[0])

        class_score = preds[:, pred_index]

    # Gradient of predicted class score wrt conv feature map
    grads = tape.gradient(class_score, conv_outputs)

    conv_outputs = conv_outputs[0]   # (7, 7, 2048)
    grads = grads[0]                 # (7, 7, 2048)

    # Channel importance weights
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1))  # (2048,)

    # Weighted sum of channels
    heatmap = tf.reduce_sum(conv_outputs * pooled_grads, axis=-1)  # (7, 7)

    # ReLU + normalize
    heatmap = tf.maximum(heatmap, 0)
    heatmap = heatmap / (tf.reduce_max(heatmap) + 1e-8)

    return heatmap.numpy()
# =========================
# OVERLAY
# =========================
def overlay_heatmap(img_path, heatmap, alpha=0.4):
    original_bgr = cv2.imread(img_path)
    original_rgb = cv2.cvtColor(original_bgr, cv2.COLOR_BGR2RGB)

    heatmap_resized = cv2.resize(heatmap, (original_rgb.shape[1], original_rgb.shape[0]))
    heatmap_uint8 = np.uint8(255 * heatmap_resized)

    heatmap_color = cv2.applyColorMap(heatmap_uint8, cv2.COLORMAP_JET)
    heatmap_color = cv2.cvtColor(heatmap_color, cv2.COLOR_BGR2RGB)

    overlay = cv2.addWeighted(original_rgb, 1 - alpha, heatmap_color, alpha, 0)
    return original_rgb, heatmap_resized, overlay

# =========================
# RUN ON 3 IMAGES
# =========================
results = []

for img_path in IMAGE_PATHS:
    print("\n" + "=" * 70)
    print("Image:", img_path)

    img_array = load_and_preprocess_image(img_path)
    preds = model.predict(img_array, verbose=0)[0]

    pred_idx = int(np.argmax(preds))
    pred_class = class_names[pred_idx]
    confidence = float(preds[pred_idx])

    sorted_probs = sorted(zip(class_names, preds), key=lambda x: x[1], reverse=True)

    print("Predicted class:", pred_class)
    print(f"Confidence: {confidence:.4f} ({confidence*100:.2f}%)")
    print("\nTop 5 predictions:")
    for cls, prob in sorted_probs[:5]:
        print(f"  {cls:25s} {prob:.4f} ({prob*100:.2f}%)")

    heatmap = make_gradcam_heatmap(
        img_array=img_array,
        model=model,
        base_model=base_model,
        pred_index=pred_idx
    )


    original_rgb, heatmap_resized, overlay = overlay_heatmap(img_path, heatmap)

    results.append({
        "img_path": img_path,
        "pred_class": pred_class,
        "confidence": confidence,
        "probs": sorted_probs,
        "original": original_rgb,
        "heatmap": heatmap_resized,
        "overlay": overlay
    })

# =========================
# SHOW RESULTS
# =========================
for r in results:
    plt.figure(figsize=(15, 4))

    plt.subplot(1, 3, 1)
    plt.imshow(r["original"])
    plt.title("Original")
    plt.axis("off")

    plt.subplot(1, 3, 2)
    plt.imshow(r["heatmap"], cmap="jet")
    plt.title("Grad-CAM Heatmap")
    plt.axis("off")

    plt.subplot(1, 3, 3)
    plt.imshow(r["overlay"])
    plt.title(f'{r["pred_class"]}\n{r["confidence"]*100:.2f}%')
    plt.axis("off")

    plt.tight_layout()
    plt.show()
