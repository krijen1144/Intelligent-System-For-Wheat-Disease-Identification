# %%
import os
import json
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# %%
TRAIN_DIR = r"C:\Users\KristianHaltenJensen\Noroff\Bachelor\archive (5)\data – Kopi\train"
VALID_DIR = r"C:\Users\KristianHaltenJensen\Noroff\Bachelor\archive (5)\data – Kopi\valid"
TEST_DIR = r"C:\Users\KristianHaltenJensen\Noroff\Bachelor\archive (5)\data – Kopi\test"

# %%
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS_HEAD = 50
EPOCHS_FINE = 50
FINE_TUNE_AT = 120
LR_HEAD = 1e-4
LR_FINE = 1e-5

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=25,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.25,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2],
    fill_mode='nearest'
)

valid_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen  = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=True
)


valid_generator = valid_datagen.flow_from_directory(
    VALID_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)
# Out:
# Found 11132 images belonging to 12 classes.
# Found 240 images belonging to 12 classes.
# Found 600 images belonging to 12 classes.

# %%
num_classes = train_generator.num_classes
class_names = list(train_generator.class_indices.keys())
print("Classes:", num_classes)
print(class_names)

with open("class_names.json", "w", encoding="utf-8") as f:
    json.dump(class_names, f, indent=2)
# Out:
# Classes: 12
# ['Black Rust', 'Blast', 'Brown Rust', 'Common Root Rot', 'Fusarium Head Blight', 'Healthy', 'Leaf Blight', 'Mildew', 'Septoria', 'Smut', 'Tan spot', 'Yellow Rust']

# %%
base_model = ResNet50(
    weights="imagenet",
    include_top=False,
    input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3),
)
base_model.trainable = False

inputs = layers.Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
x = base_model(inputs, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.BatchNormalization()(x) 
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(num_classes, activation="softmax")(x)

model = models.Model(inputs, outputs)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ resnet50 (Functional)                │ (None, 7, 7, 2048)          │      23,587,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 2048)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 2048)                │           8,192 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 12)                  │          24,588 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 23,620,492 (90.11 MB)
#  Trainable params: 28,684 (112.05 KB)
#  Non-trainable params: 23,591,808 (90.00 MB)

# %%
callbacks = [
    EarlyStopping(
        monitor="val_loss",
        patience=5,
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.2,
        patience=2,
        min_lr=1e-7,
        verbose=1
    ),
    ModelCheckpoint(
        "ResNet50_WPD.keras",
        monitor="val_accuracy",
        save_best_only=True,
        verbose=1
    )
]

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LR_HEAD),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)


history_head = model.fit(
    train_generator,
    epochs=EPOCHS_HEAD,
    validation_data=valid_generator,
    callbacks = callbacks
)
# Out:
# C:\Users\KristianHaltenJensen\anaconda4\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 739s 2s/step - accuracy: 0.1734 - loss: 3.2454 - val_accuracy: 0.4292 - val_loss: 2.0073
# Epoch 2/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 548s 2s/step - accuracy: 0.4473 - loss: 1.9046 - val_accuracy: 0.5083 - val_loss: 1.9050
# Epoch 3/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 454s 1s/step - accuracy: 0.5309 - loss: 1.6034 - val_accuracy: 0.5667 - val_loss: 1.7784
# Epoch 4/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 441s 1s/step - accuracy: 0.5961 - loss: 1.3556 - val_accuracy: 0.5750 - val_loss: 1.7079
# Epoch 5/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 434s 1s/step - accuracy: 0.6119 - loss: 1.2731 - val_accuracy: 0.6125 - val_loss: 1.6075
# Epoch 6/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 429s 1s/step - accuracy: 0.6238 - loss: 1.2148 - val_accuracy: 0.6250 - val_loss: 1.5819
# Epoch 7/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━
50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 469s 1s/step - accuracy: 0.7354 - loss: 0.7713 - val_accuracy: 0.7125 - val_loss: 1.2845
# Epoch 31/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 511s 1s/step - accuracy: 0.7451 - loss: 0.7634 - val_accuracy: 0.7042 - val_loss: 1.2517
# Epoch 32/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 554s 2s/step - accuracy: 0.7401 - loss: 0.7831 - val_accuracy: 0.7083 - val_loss: 1.2870
# Epoch 33/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 511s 1s/step - accuracy: 0.7512 - loss: 0.7228 - val_accuracy: 0.7083 - val_loss: 1.2552
# Epoch 34/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 535s 2s/step - accuracy: 0.7538 - loss: 0.7325 - val_accuracy: 0.7208 - val_loss: 1.2500
# Epoch 35/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 569s 2s/step - accuracy: 0.7517 - loss: 0.7325 - val_accuracy: 0.7208 - val_loss: 1.2157
# Epoch 36/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 459s 1s/step - accuracy: 0.7472 - loss: 0.7405 - val_accuracy: 0.7125 - val_loss: 1.2397
# Epoch 37/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 440s 1s/step - accuracy: 0.7488 - loss: 0.7385 - val_accuracy: 0.7083 - val_loss: 1.2301
# Epoch 38/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 444s 1s/step - accuracy: 0.7604 - loss: 0.7118 - val_accuracy: 0.6958 - val_loss: 1.2493
# Epoch 39/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 445s 1s/step - accuracy: 0.7513 - loss: 0.7256 - val_accuracy: 0.7042 - val_loss: 1.2708
# Epoch 40/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 437s 1s/step - accuracy: 0.7516 - loss: 0.7247 - val_accuracy: 0.7250 - val_loss: 1.2649
# Epoch 41/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 434s 1s/step - accuracy: 0.7547 - loss: 0.7329 - val_accuracy: 0.7208 - val_loss: 1.2175
# Epoch 42/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 435s 1s/step - accuracy: 0.7631 - loss: 0.6939 - val_accuracy: 0.7208 - val_loss: 1.1996
# Epoch 43/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 438s 1s/step - accuracy: 0.7508 - loss: 0.7237 - val_accuracy: 0.7083 - val_loss: 1.2525
# Epoch 44/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 433s 1s/step - accuracy: 0.7622 - loss: 0.7103 - val_accuracy: 0.7250 - val_loss: 1.2943
# Epoch 45/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 438s 1s/step - accuracy: 0.7652 - loss: 0.6854 - val_accuracy: 0.7208 - val_loss: 1.2437
# Epoch 46/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 436s 1s/step - accuracy: 0.7584 - loss: 0.7043 - val_accuracy: 0.7250 - val_loss: 1.2860
# Epoch 47/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 450s 1s/step - accuracy: 0.7615 - loss: 0.6965 - val_accuracy: 0.7208 - val_loss: 1.2716
# Epoch 48/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 439s 1s/step - accuracy: 0.7561 - loss: 0.7029 - val_accuracy: 0.7208 - val_loss: 1.3062
# Epoch 49/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 440s 1s/step - accuracy: 0.7604 - loss: 0.6983 - val_accuracy: 0.7250 - val_loss: 1.3001
# Epoch 50/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 438s 1s/step - accuracy: 0.7644 - loss: 0.6902 - val_accuracy: 0.7375 - val_loss: 1.2913

# %%
base_model.trainable = True
for layer in base_model.layers[:FINE_TUNE_AT]:
    layer.trainable = False

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

history_ft = model.fit(
    train_generator,
    epochs=EPOCHS_FINE,
    validation_data=valid_generator,
    callbacks = callbacks
)
# Out:
# Epoch 1/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 699s 2s/step - accuracy: 0.7356 - loss: 0.8002 - val_accuracy: 0.7417 - val_loss: 1.2376
# Epoch 2/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 656s 2s/step - accuracy: 0.7750 - loss: 0.6809 - val_accuracy: 0.7583 - val_loss: 1.1984
# Epoch 3/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 
50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 558s 2s/step - accuracy: 0.9615 - loss: 0.0930 - val_accuracy: 0.9167 - val_loss: 1.1267
# Epoch 50/50
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 559s 2s/step - accuracy: 0.9593 - loss: 0.0940 - val_accuracy: 0.9083 - val_loss: 1.1522

# %%
model.save('ResNet50_WPD.keras')

# %%
with open("training_history_ResNet50_2.json", "w", encoding="utf-8") as f:
    json.dump(history_head.history, f, indent=2)

print("Saved: training_history_ResNet50_2.json")
# Out:
# Saved: training_history_ResNet50_2.json

# %%
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)

print(f"Test loss: {test_loss:.4f}")
print(f"Test accuracy: {test_accuracy:.4f}")
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.8915 - loss: 1.0609
# Test loss: 1.2454
# Test accuracy: 0.8967

# %%
test_metrics = {
    "test_loss": float(test_loss),
    "test_accuracy": float(test_accuracy)
}

with open("test_metric_ResNet50_2.json", "w", encoding="utf-8") as f:
    json.dump(test_metrics, f, indent=2)
# Out:
# Saved test_metrics_ResNet50_2.json

# %%
import numpy as np

y_pred_probs = model.predict(test_generator, verbose=1)
y_pred = np.argmax(y_pred_probs, axis=1)

y_true = test_generator.classes
class_names = list(test_generator.class_indices.keys())
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 911ms/step

# %%
from sklearn.metrics import classification_report

print(classification_report(
    y_true,
    y_pred,
    target_names=class_names
))
# Out:
#                            precision    recall  f1-score   support
#
#           black_rust_test       1.00      0.82      0.90        50
#                blast_test       0.96      1.00      0.98        50
#           brown_rust_test       0.84      0.98      0.91        50
#      common_root_rot_test       1.00      1.00      1.00        50
# fusarium_head_blight_test       1.00      1.00      1.00        50
#              healthy_test       0.71      0.10      0.18        50
#          leaf_blight_test       0.96      0.96      0.96        50
#               mildew_test       1.00      0.96      0.98        50
#             septoria_test       1.00      1.00      1.00        50
#                 smut_test       1.00      0.98      0.99        50
#             tan_spot_test       0.94      0.96      0.95        50
#          yellow_rust_test       0.53      1.00      0.69        50
#
#                  accuracy                           0.90       600
#                 macro avg       0.91      0.90      0.88       600
#              weighted avg       0.91      0.90      0.88       600

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd

cm = confusion_matrix(y_true, y_pred)

cm_df = pd.DataFrame(
    cm,
    index=class_names,      # True labels (rows)
    columns=class_names     # Predicted labels (columns)
)

print(cm_df)
# Out:
#                            black_rust_test  blast_test  brown_rust_test  \
# black_rust_test                         44           0                6
# blast_test                               0          50                0
# brown_rust_test                          0           0               48
# common_root_rot_test                     0           0                0
# fusarium_head_blight_test                0           0                0
# healthy_test                             1           2                0
# leaf_blight_test                         0           0                0
# mildew_test                              0           0                0
# septoria_test                            0           0                0
# smut_test                                0           0                0
# tan_spot_test                            0           0                0
# yellow_rust_test                         0           0                0
#
#                            common_root_rot_test  fusarium_head_blight_test  \
# black_rust_test                               0                          0
# blast_test                                    0                          0
# brown_rust_test                               0                          0
# common_root_rot_test                         50                          0
# fusarium_head_blight_test                     0                         50
# healthy_test                                  0                          0
# leaf_blight_test                              0                          0
# mildew_test                                   0                          0
# septoria_test                                 0                          0
# smut_test                                     0                          0
# tan_spot_test                                 0                          0
# yellow_rust_test                              0                          0
#
#                            healthy_test  leaf_blight_test  mildew_test  \
# black_rust_test                       0                 0            0
# blast_test                            0                 0            0
# brown_rust_test                       0                 0            0
# common_root_rot_test                  0                 0            0
# fusarium_head_blight_test             0                 0            0
# healthy_test                          4                 0            0
# leaf_blight_test                      0                49            0
# mildew_test                           0                 0           50
# septoria_test                         0                 3            0
# smut_test                             0                 0            0
# tan_spot_test                         0                 2            0
# yellow_rust_test                      0                 0            0
#
#                            septoria_test  smut_test  tan_spot_test  \
# black_rust_test                        0          0              0
# blast_test                             0          0              0
# brown_rust_test                        0          0              0
# common_root_rot_test                   0          0              0
# fusarium_head_blight_test              0          0              0
# healthy_test                           0          0              0
# leaf_blight_test                       0          0              1
# mildew_test                            0          0              0
# septoria_test                         47          0              0
# smut_test                              0         50              0
# tan_spot_test                          0          0             48
# yellow_rust_test                       0          0              0
#
#                            yellow_rust_test
# black_rust_test                           0
# blast_test                                0
# brown_rust_test                           2
# common_root_rot_test                      0
# fusarium_head_blight_test                 0
# healthy_test                             43
# leaf_blight_test                          0
# mildew_test                               0
# septoria_test                             0
# smut_test                                 0
# tan_spot_test                             0
# yellow_rust_test                         50

# %%
cm_df
# Out:
#                            black_rust_test  blast_test  brown_rust_test  \
# black_rust_test                         44           0                6
# blast_test                               0          50                0
# brown_rust_test                          0           0               48
# common_root_rot_test                     0           0                0
# fusarium_head_blight_test                0           0                0
# healthy_test                             1           2                0
# leaf_blight_test                         0           0                0
# mildew_test                              0           0                0
# septoria_test                            0           0                0
# smut_test                                0           0                0
# tan_spot_test                            0           0                0
# yellow_rust_test                         0           0                0
#
#                            common_root_rot_test  fusarium_head_blight_test  \
# black_rust_test                               0                          0
# blast_test                                    0                          0
# brown_rust_test                               0                          0
# common_root_rot_test                         50                          0
# fusarium_head_blight_test                     0                         50
# healthy_test                                  0                          0
# leaf_blight_test                              0                          0
# mildew_test                                   0                          0
# septoria_test                                 0                          0
# smut_test                                     0                          0
# tan_spot_test                                 0                          0
# yellow_rust_test                              0                          0
#
#                            healthy_test  leaf_blight_test  mildew_test  \
# black_rust_test                       0                 0            0
# blast_test                            0                 0            0
# brown_rust_test                       0                 0            0
# common_root_rot_test                  0                 0            0
# fusarium_head_blight_test             0                 0            0
# healthy_test                          4                 0            0
# leaf_blight_test                      0                49            0
# mildew_test                           0                 0           50
# septoria_test                         0                 3            0
# smut_test                             0                 0            0
# tan_spot_test                         0                 2            0
# yellow_rust_test                      0                 0            0
#
#                            septoria_test  smut_test  tan_spot_test  \
# black_rust_test                        0          0              0
# blast_test                             0          0              0
# brown_rust_test                        0          0              0
# common_root_rot_test                   0          0              0
# fusarium_head_blight_test              0          0              0
# healthy_test                           0          0              0
# leaf_blight_test                       0          0              1
# mildew_test                            0          0              0
# septoria_test                         47          0              0
# smut_test                              0         50              0
# tan_spot_test                          0          0             48
# yellow_rust_test                       0          0              0
#
#                            yellow_rust_test
# black_rust_test                           0
# blast_test                                0
# brown_rust_test                           2
# common_root_rot_test                      0
# fusarium_head_blight_test                 0
# healthy_test                             43
# leaf_blight_test                          0
# mildew_test                               0
# septoria_test                             0
# smut_test                                 0
# tan_spot_test                             0
# yellow_rust_test                         50
